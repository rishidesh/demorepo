# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv('Advertising.csv')

# %%
data
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
data.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
data.tail()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
data.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %% [raw]
# std is high - then spread is also high

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %% [markdown]
# ### EDA

# %%
data.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
sns.displot(x=data.TV,kde=True)

# %%
sns.histplot(x=data.Radio,kde=True)
# Out:
# <AxesSubplot:xlabel='Radio', ylabel='Count'>

# %%
sns.histplot(x=data.Newspaper,kde=True)
# Out:
# <AxesSubplot:xlabel='Newspaper', ylabel='Count'>

# %%
sns.displot(x=data.TV,kde=True)

# %%
sns.displot(x=data.Newspaper,kde=True)

# %%
data.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
sns.scatterplot(x='TV',y='Sales',data=data)
# Out:
# <AxesSubplot:xlabel='TV', ylabel='Sales'>

# %%
plt.plot(data.TV)
plt.plot(data.Sales)

# %%
sns.relplot(x='Radio',y='Sales',data=data)

# %%
sns.relplot(x='Newspaper',y='Sales',data=data)

# %%
sns.pairplot(data)

# %% [markdown]
# ### Data Preprocessing & Feature Engg.

# %%
data.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
sns.boxplot(x='TV',data=data)
# Out:
# <AxesSubplot:xlabel='TV'>

# %%
sns.boxplot(x='Radio',data=data)
# Out:
# <AxesSubplot:xlabel='Radio'>

# %%
sns.boxplot(x='Newspaper',data=data)
# Out:
# <AxesSubplot:xlabel='Newspaper'>

# %% [markdown]
# ### Feature Selection

# %%
l1=['Unnamed: 0']
data.drop(l1,axis=1,inplace=True)

# %%
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
sns.heatmap(data.drop('Sales',axis=1).corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
data.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.782224
# Radio      0.054809  1.000000   0.354104  0.576223
# Newspaper  0.056648  0.354104   1.000000  0.228299
# Sales      0.782224  0.576223   0.228299  1.000000

# %% [markdown]
# #### Model Creation

# %%
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
X=data[['TV','Radio','Newspaper']]
y=data.Sales

# %%
X
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=10)

# %%
print(len(X_test))
print(len(X_train))
# Out:
# 40
# 160

# %%
X_test
# Out:
#         TV  Radio  Newspaper
# 59   210.7   29.5        9.3
# 5      8.7   48.9       75.0
# 20   218.4   27.7       53.4
# 198  283.6   42.0       66.2
# 52   216.4   41.7       39.6
# 19   147.3   23.9       19.1
# 162  188.4   18.1       25.6
# 55   198.9   49.4       60.0
# 69   216.8   43.9       27.2
# 2     17.2   45.9       69.3
# 98   289.7   42.3       51.2
# 10    66.1    5.8       24.2
# 75    16.9   43.7       89.4
# 142  220.5   33.2       37.9
# 124  229.5   32.3       74.2
# 63   102.7   29.6        8.4
# 109  255.4   26.9        5.5
# 78     5.4   29.9        9.4
# 111  241.7   38.0       23.2
# 185  205.0   45.1       19.6
# 154  187.8   21.1        9.5
# 130    0.7   39.6        8.7
# 61   261.3   42.7       54.7
# 87   110.7   40.6       63.2
# 102  280.2   10.1       21.4
# 121   18.8   21.7       50.4
# 136   25.6   39.0        9.3
# 1     44.5   39.3       45.1
# 47   239.9   41.5       18.5
# 172   19.6   20.1       17.0
# 159  131.7   18.4       34.6
# ...

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression()
LR.fit(X_train,y_train)
y_predict=LR.predict(X_test)

# %%
y_test
# Out:
# 59     18.4
# 5       7.2
# 20     18.0
# 198    25.5
# 52     22.6
# 19     14.6
# 162    14.9
# 55     23.7
# 69     22.3
# 2       9.3
# 98     25.4
# 10      8.6
# 75      8.7
# 142    20.1
# 124    19.7
# 63     14.0
# 109    19.8
# 78      5.3
# 111    21.8
# 185    22.6
# 154    15.6
# 130     1.6
# 61     24.2
# 87     16.0
# 102    14.8
# 121     7.0
# 136     9.5
# 1      10.4
# 47     23.2
# 172     7.6
# 159    12.9
# 39     21.5
# 76      6.9
# 91      7.3
# 35     12.8
# 178    11.8
# 127     8.8
# 169    15.0
# 46     10.6
# 174    11.5
# Name: Sales, dtype: float64

# %%
y_predict
# Out:
# array([18.1625299 , 12.92663232, 18.0531098 , 23.64464668, 20.70438374,
#        14.28227997, 14.94493548, 21.38232981, 21.17508238, 12.73110461,
#        24.00312134,  7.21544071, 12.24762152, 19.24345998, 19.38241854,
#        13.45643798, 19.6247089 ,  9.2531648 , 21.13268075, 20.90762408,
#        15.53485445, 10.92529369, 22.82955184, 15.8122438 , 17.42515749,
#         8.16218669, 11.89783444, 12.70337575, 21.74138085,  7.96215368,
#        12.50099965, 20.45535282,  4.72120047,  4.72259288, 16.75292333,
#        15.75804986,  6.74415499, 17.73477354,  9.01591827, 13.617599  ])

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
r2score=r2_score(y_test,y_predict)

# %%
r2score
# Out:
# 0.8353672324670592

# %%
X_test.shape
# Out:
# (40, 3)

# %%
adjusted_r2 = 1-(1-0.8353)*(40-1)/(40-3-1)
adjusted_r2
# Out:
# 0.821575

# %%
import math
print(mean_squared_error(y_test,y_predict))
print(math.sqrt(mean_squared_error(y_test,y_predict)))
# Out:
# 6.7004867565288775
# 2.5885298446278107

# %%
print(mean_absolute_error(y_test,y_predict))
# Out:
# 1.8850130310423154

# %%
a=int(input("Enter TV spend : "))
b=int(input("Enter Radio spend : "))
c=int(input("Enter NP spend : "))
expsale=LR.predict([[a,b,c]])
print("your expected sale is : ",expsale)
# Out:
# Enter TV spend : 85
# Enter Radio spend : 50
# Enter NP spend : 25
# your expected sale is :  [16.59069786]
# C:\Users\deshm\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
expsale
# Out:
# array([16.59069786])

# %% [markdown]
# # 50_Startup_files

# %% [markdown]
# #### Analysis

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('50_Startups_LR.csv')
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df.shape
# Out:
# (50, 5)

# %%
df.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit'], dtype='object')

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df.tail()
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 45    1000.23       124153.04          1903.93    New York  64926.08
# 46    1315.46       115816.21        297114.46     Florida  49490.75
# 47       0.00       135426.92             0.00  California  42559.73
# 48     542.05        51743.15             0.00    New York  35673.41
# 49       0.00       116983.80         45173.06  California  14681.40

# %%
df.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %% [raw]
# 1) the spread of data of Marketing spend is more.
# 2) once there is 0 investment in R&D and Marketing
# 3) Marketing spend is way more than others.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# ## EDA

# %% [markdown]
# #### Univariate Analysis

# %%
sns.histplot(x='R&D Spend',data=df,kde=True)
# Out:
# <AxesSubplot:xlabel='R&D Spend', ylabel='Count'>

# %%
sns.displot(x='Marketing Spend',data=df,kde=True)

# %%
sns.displot(x='Administration',data=df,kde=True)

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
sns.relplot(x='R&D Spend',y='Profit',data=df,hue='State')

# %%
sns.relplot(x='Administration',y='Profit',data=df,hue='State')

# %%
sns.relplot(x='Marketing Spend',y='Profit',data=df,hue='State')
plt.show()

# %%
sns.scatterplot(x='R&D Spend',y='Profit',data=df,hue='State')
plt.show()

# %%
sns.barplot(x='State',y='Profit',data=df)
# Out:
# <AxesSubplot:xlabel='State', ylabel='Profit'>

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# Minimum profit is noted in California State.

# %% [markdown]
# ### Data Preprocessing

# %%
df.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %% [markdown]
#  It has no missing values

# %% [markdown]
# #### Outlier handling

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
sns.boxplot(x='R&D Spend',data=df)
# Out:
# <AxesSubplot:xlabel='R&D Spend'>

# %%
sns.boxplot(x='Administration',data=df)
# Out:
# <AxesSubplot:xlabel='Administration'>

# %%
sns.boxplot(x='Marketing Spend',data=df)
# Out:
# <AxesSubplot:xlabel='Marketing Spend'>

# %%
df['State'].replace('New York',1,inplace=True)
df['State'].replace('California',2,inplace=True)
df['State'].replace('Florida',3,inplace=True)

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend  State     Profit
# 0   165349.20       136897.80        471784.10      1  192261.83
# 1   162597.70       151377.59        443898.53      2  191792.06
# 2   153441.51       101145.55        407934.54      3  191050.39
# 3   144372.41       118671.85        383199.62      1  182901.99
# 4   142107.34        91391.77        366168.42      3  166187.94
# 5   131876.90        99814.71        362861.36      1  156991.12
# 6   134615.46       147198.87        127716.82      2  156122.51
# 7   130298.13       145530.06        323876.68      3  155752.60
# 8   120542.52       148718.95        311613.29      1  152211.77
# 9   123334.88       108679.17        304981.62      2  149759.96
# 10  101913.08       110594.11        229160.95      3  146121.95
# 11  100671.96        91790.61        249744.55      2  144259.40
# 12   93863.75       127320.38        249839.44      3  141585.52
# ...

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend  State     Profit
# 0  165349.20       136897.80        471784.10      1  192261.83
# 1  162597.70       151377.59        443898.53      2  191792.06
# 2  153441.51       101145.55        407934.54      3  191050.39
# 3  144372.41       118671.85        383199.62      1  182901.99
# 4  142107.34        91391.77        366168.42      3  166187.94

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
d1=['State']
data1 = sc.fit_transform(df.drop(d1,axis=1))

# %%
data1
# Out:
# array([[1.        , 0.65174393, 1.        , 1.        ],
#        [0.98335946, 0.76197173, 0.94089337, 0.99735461],
#        [0.92798459, 0.37957895, 0.8646636 , 0.99317808],
#        [0.87313643, 0.51299839, 0.81223513, 0.94729239],
#        [0.85943772, 0.30532804, 0.77613557, 0.85317138],
#        [0.797566  , 0.3694479 , 0.76912588, 0.80138177],
#        [0.81412828, 0.73016111, 0.27071031, 0.79649041],
#        [0.7880179 , 0.71745725, 0.68649342, 0.79440736],
#        [0.72901786, 0.74173276, 0.66049977, 0.77446805],
#        [0.74590551, 0.43692884, 0.64644319, 0.7606613 ],
#        [0.61635061, 0.45150637, 0.48573267, 0.74017475],
#        [0.60884455, 0.30836422, 0.52936195, 0.72968626],
#        [0.56766982, 0.57883556, 0.52956308, 0.71462897],
#        [0.55635219, 0.64106561, 0.53555202, 0.67364377],
#        [0.72539353, 0.8013272 , 0.54370828, 0.66404417],
#        [0.69261666, 0.54302973, 0.55486446, 0.64892083],
# ...

# %%
con_data=df['State']
con_data
# Out:
# 0     1
# 1     2
# 2     3
# 3     1
# 4     3
# 5     1
# 6     2
# 7     3
# 8     1
# 9     2
# 10    3
# 11    2
# 12    3
# 13    2
# 14    3
# 15    1
# 16    2
# 17    1
# 18    3
# 19    1
# 20    2
# 21    1
# 22    3
# 23    3
# 24    1
# 25    2
# 26    3
# 27    1
# 28    3
# 29    1
# 30    3
# 31    1
# 32    2
# 33    3
# 34    2
# 35    1
# 36    3
# 37    2
# 38    1
# 39    2
# 40    2
# 41    3
# 42    2
# 43    1
# 44    2
# 45    1
# 46    3
# 47    2
# 48    1
# 49    2
# Name: State, dtype: int64

# %%
df.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit'], dtype='object')

# %%
data2=pd.DataFrame(data1,columns=['R&D Spend','Administration','Marketing Spend','Profit'])
data2
# Out:
#     R&D Spend  Administration  Marketing Spend    Profit
# 0    1.000000        0.651744         1.000000  1.000000
# 1    0.983359        0.761972         0.940893  0.997355
# 2    0.927985        0.379579         0.864664  0.993178
# 3    0.873136        0.512998         0.812235  0.947292
# 4    0.859438        0.305328         0.776136  0.853171
# 5    0.797566        0.369448         0.769126  0.801382
# 6    0.814128        0.730161         0.270710  0.796490
# 7    0.788018        0.717457         0.686493  0.794407
# 8    0.729018        0.741733         0.660500  0.774468
# 9    0.745906        0.436929         0.646443  0.760661
# 10   0.616351        0.451506         0.485733  0.740175
# 11   0.608845        0.308364         0.529362  0.729686
# 12   0.567670        0.578836         0.529563  0.714629
# 13   0.556352        0.641066         0.535552  0.673644
# 14   0.725394        0.801327         0.543708  0.664044
# ...

# %%
final_data = pd.concat([data2,con_data],axis=1)

# %%
final_data
# Out:
#     R&D Spend  Administration  Marketing Spend    Profit  State
# 0    1.000000        0.651744         1.000000  1.000000      1
# 1    0.983359        0.761972         0.940893  0.997355      2
# 2    0.927985        0.379579         0.864664  0.993178      3
# 3    0.873136        0.512998         0.812235  0.947292      1
# 4    0.859438        0.305328         0.776136  0.853171      3
# 5    0.797566        0.369448         0.769126  0.801382      1
# 6    0.814128        0.730161         0.270710  0.796490      2
# 7    0.788018        0.717457         0.686493  0.794407      3
# 8    0.729018        0.741733         0.660500  0.774468      1
# 9    0.745906        0.436929         0.646443  0.760661      2
# 10   0.616351        0.451506         0.485733  0.740175      3
# 11   0.608845        0.308364         0.529362  0.729686      2
# 12   0.567670        0.578836         0.529563  0.714629      3
# 13   0.556352        0.641066         0.535552  0.673644      2
# ...

# %%
data3=final_data[['R&D Spend','Administration','Marketing Spend']]
data3
# Out:
#     R&D Spend  Administration  Marketing Spend
# 0    1.000000        0.651744         1.000000
# 1    0.983359        0.761972         0.940893
# 2    0.927985        0.379579         0.864664
# 3    0.873136        0.512998         0.812235
# 4    0.859438        0.305328         0.776136
# 5    0.797566        0.369448         0.769126
# 6    0.814128        0.730161         0.270710
# 7    0.788018        0.717457         0.686493
# 8    0.729018        0.741733         0.660500
# 9    0.745906        0.436929         0.646443
# 10   0.616351        0.451506         0.485733
# 11   0.608845        0.308364         0.529362
# 12   0.567670        0.578836         0.529563
# 13   0.556352        0.641066         0.535552
# 14   0.725394        0.801327         0.543708
# 15   0.692617        0.543030         0.554864
# 16   0.471808        0.535270         0.560312
# 17   0.572468        0.714013         0.598948
# 18   0.554881        0.478772         0.625116
# ...

# %%
data3.head()
# Out:
#    R&D Spend  Administration  Marketing Spend
# 0   1.000000        0.651744         1.000000
# 1   0.983359        0.761972         0.940893
# 2   0.927985        0.379579         0.864664
# 3   0.873136        0.512998         0.812235
# 4   0.859438        0.305328         0.776136

# %% [markdown]
# #### Feature Selection

# %%
sns.heatmap(data3.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Model Creation

# %%
final_data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend    Profit  State
# 0   1.000000        0.651744         1.000000  1.000000      1
# 1   0.983359        0.761972         0.940893  0.997355      2
# 2   0.927985        0.379579         0.864664  0.993178      3
# 3   0.873136        0.512998         0.812235  0.947292      1
# 4   0.859438        0.305328         0.776136  0.853171      3

# %%
X=final_data.iloc[:,:-2]
y=final_data['Profit']

# %%
X
# Out:
#     R&D Spend  Administration  Marketing Spend
# 0    1.000000        0.651744         1.000000
# 1    0.983359        0.761972         0.940893
# 2    0.927985        0.379579         0.864664
# 3    0.873136        0.512998         0.812235
# 4    0.859438        0.305328         0.776136
# 5    0.797566        0.369448         0.769126
# 6    0.814128        0.730161         0.270710
# 7    0.788018        0.717457         0.686493
# 8    0.729018        0.741733         0.660500
# 9    0.745906        0.436929         0.646443
# 10   0.616351        0.451506         0.485733
# 11   0.608845        0.308364         0.529362
# 12   0.567670        0.578836         0.529563
# 13   0.556352        0.641066         0.535552
# 14   0.725394        0.801327         0.543708
# 15   0.692617        0.543030         0.554864
# 16   0.471808        0.535270         0.560312
# 17   0.572468        0.714013         0.598948
# 18   0.554881        0.478772         0.625116
# ...

# %%
y
# Out:
# 0     1.000000
# 1     0.997355
# 2     0.993178
# 3     0.947292
# 4     0.853171
# 5     0.801382
# 6     0.796490
# 7     0.794407
# 8     0.774468
# 9     0.760661
# 10    0.740175
# 11    0.729686
# 12    0.714629
# 13    0.673644
# 14    0.664044
# 15    0.648921
# 16    0.632454
# 17    0.623317
# 18    0.617103
# 19    0.608713
# 20    0.584482
# 21    0.544157
# 22    0.538747
# 23    0.529634
# 24    0.528609
# 25    0.522146
# 26    0.512737
# 27    0.508654
# 28    0.498934
# 29    0.486108
# 30    0.480099
# 31    0.466280
# 32    0.465966
# 33    0.462312
# 34    0.461939
# 35    0.460626
# 36    0.428126
# 37    0.423852
# 38    0.374747
# 39    0.373489
# 40    0.357914
# 41    0.355430
# 42    0.319951
# 43    0.310156
# 44    0.284485
# 45    0.282940
# 46    0.196020
# 47    0.156990
# 48    0.118211
# 49    0.000000
# Name: Profit, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=50)

# %%
X_train
# Out:
#     R&D Spend  Administration  Marketing Spend
# 18   0.554881        0.478772         0.625116
# 46   0.007956        0.491260         0.629768
# 12   0.567670        0.578836         0.529563
# 23   0.408424        0.414638         0.645992
# 25   0.391080        0.671958         0.292427
# 3    0.873136        0.512998         0.812235
# 39   0.233194        0.241309         0.370931
# 15   0.692617        0.543030         0.554864
# 41   0.168691        0.254469         0.348614
# 19   0.522650        0.778236         0.000000
# 49   0.000000        0.500148         0.095749
# 0    1.000000        0.651744         1.000000
# 9    0.745906        0.436929         0.646443
# 10   0.616351        0.451506         0.485733
# 21   0.474084        0.780210         0.635327
# 17   0.572468        0.714013         0.598948
# 47   0.000000        0.640547         0.000000
# 20   0.461169        0.476424         0.633053
# 40   0.173901        0.512041         0.366260
# ...

# %%
X_test
# Out:
#     R&D Spend  Administration  Marketing Spend
# 34   0.280776        0.810055         0.446810
# 36   0.173353        0.576825         0.426311
# 1    0.983359        0.761972         0.940893
# 38   0.122345        0.111636         0.392690
# 8    0.729018        0.741733         0.660500
# 16   0.471808        0.535270         0.560312
# 35   0.278284        0.257032         0.435618
# 13   0.556352        0.641066         0.535552
# 29   0.396769        0.774566         0.227092
# 24   0.465947        0.365388         0.297964

# %%
y_train
# Out:
# 18    0.617103
# 46    0.196020
# 12    0.714629
# 23    0.529634
# 25    0.522146
# 3     0.947292
# 39    0.373489
# 15    0.648921
# 41    0.355430
# 19    0.608713
# 49    0.000000
# 0     1.000000
# 9     0.760661
# 10    0.740175
# 21    0.544157
# 17    0.623317
# 47    0.156990
# 20    0.584482
# 40    0.357914
# 44    0.284485
# 26    0.512737
# 27    0.508654
# 28    0.498934
# 14    0.664044
# 43    0.310156
# 7     0.794407
# 31    0.466280
# 2     0.993178
# 5     0.801382
# 22    0.538747
# 42    0.319951
# 37    0.423852
# 6     0.796490
# 4     0.853171
# 30    0.480099
# 33    0.462312
# 45    0.282940
# 11    0.729686
# 32    0.465966
# 48    0.118211
# Name: Profit, dtype: float64

# %%
y_test
# Out:
# 34    0.461939
# 36    0.428126
# 1     0.997355
# 38    0.374747
# 8     0.774468
# 16    0.632454
# 35    0.460626
# 13    0.673644
# 29    0.486108
# 24    0.528609
# Name: Profit, dtype: float64

# %%
X_train.head()
# Out:
#     R&D Spend  Administration  Marketing Spend
# 18   0.554881        0.478772         0.625116
# 46   0.007956        0.491260         0.629768
# 12   0.567670        0.578836         0.529563
# 23   0.408424        0.414638         0.645992
# 25   0.391080        0.671958         0.292427

# %%
print(len(X_train))
print(len(X_test))
# Out:
# 40
# 10

# %%
from sklearn.linear_model import LinearRegression
LR = LinearRegression()
LR.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict = LR.predict(X_test)

# %%
y_predict
# Out:
# array([0.40005426, 0.32155246, 0.97475605, 0.29474733, 0.76467902,
#        0.56394492, 0.41524097, 0.62689294, 0.48624545, 0.5563497 ])

# %%
y_test
# Out:
# 34    0.461939
# 36    0.428126
# 1     0.997355
# 38    0.374747
# 8     0.774468
# 16    0.632454
# 35    0.460626
# 13    0.673644
# 29    0.486108
# 24    0.528609
# Name: Profit, dtype: float64

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
r2score = r2_score(y_test, y_predict)

# %%
round(r2score,5)
# Out:
# 0.90283

# %%
Adj_r2score = 1-(1-r2score)*(10-1)/(10-3-1)

# %%
import math

# %%
print("r2 score :",r2score)
print("Adjusted r2score :",Adj_r2score)
print("Mean squared error :",mean_squared_error(y_test,y_predict))
print("Root mean squared error :",math.sqrt(mean_squared_error(y_test, y_predict)))
print("Mean absolute error :",mean_absolute_error(y_test, y_predict))
# Out:
# r2 score : 0.9028338938059202
# Adjusted r2score : 0.8542508407088802
# Mean squared error : 0.0031902607413898457
# Root mean squared error : 0.0564823931981449
# Mean absolute error : 0.046936873450975185

# %%
a=int(input('Enter R&D Spend : '))
b=int(input('Enter Administration Spend : '))
c=int(input('Enter Marketing Spend : '))
dummy_predict = LR.predict([[a,b,c]])
print('Profit :',dummy_predict)
# Out:
# Enter R&D Spend : 85
# Enter Administration Spend : 69
# Enter Marketing Spend : 45
# Profit : [66.87826288]
